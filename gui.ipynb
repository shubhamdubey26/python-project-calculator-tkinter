# %%
#importing modules
from tkinter import *
#assigning objet root to  tkinter package TK() having lots of gui tools
root = Tk()
#asssigning a string variable
expr =""

#fun is calle by lambda fun as soon as any button is clicked
def fun(n):
    '''here global expr is used which is declared earlier  assignig string to expr variable,
       inputs is a entry variable  which is used to assign  a value to display. '''
    global expr
   
    expr = expr+str(n)
    
    inputs.set(expr)
def Result():
    
    '''result is mathematical fun  in wich currently stored expr is usef to perform mathematical operation .
       eval() is a function which takes string as input and perform operation on input.
    total is variable used to stor string as input  which is resut of mathematical function'''
    try:
        global expr
        total = str(eval(expr))
        inputs.set(total)
    except:
        input.set("error")
def reset():
    '''reset method is created here to clear the screen 
       first we used the global expr that means already declared expr which is access from all'''
    global expr
    expr=""
    inputs.set("")

root.title("Calculator")#used to give title to the root window
root.geometry("400x700")#dimension of root window
root.configure(background ='#091844')
inputs = StringVar()#used to set the expression in dispaly

#--------------------------------design--------------------------------------

e1 =Entry(root,textvariable=inputs,background="#d9d9d9",justify='right',font=('arial',10,'bold'))
e1.place(relx =0.10,rely=0.10,height=35 ,relwidth=0.850)

b0 = Button(root,text = '''7''',command=lambda: fun('1'),height= 5, width=10,bg='black',fg='spring green')
b0.place(relx =0.10,rely=0.21,height=44,width=57)


b1 = Button(root,text = '''8''',command=lambda: fun('2'),height= 5, width=10,bg='black',fg='spring green')
b1.place(relx =0.32,rely=0.21,height=44,width=57)

b2 = Button(root,text = '''9''',command=lambda: fun('3'),height= 5, width=10,bg='black',fg='spring green')
b2.place(relx =0.54,rely=0.21,height=44,width=57)

b3 = Button(root,text = '''4''',command=lambda: fun('4'),height= 5, width=10,bg='black',fg='spring green')
b3.place(relx =0.10,rely=0.34,height=44,width=57)


b4 = Button(root,text = '''5''',command=lambda: fun('5'),height= 5, width=10,bg='black',fg='spring green')
b4.place(relx =0.32,rely=0.34,height=44,width=57)

b5 = Button(root,text = '''6''',command=lambda: fun('6'),height= 5, width=10,bg='black',fg='spring green')
b5.place(relx =0.54,rely=0.34,height=44,width=57)

b6 = Button(root,text = '''1''',command=lambda: fun('7'),height= 5, width=10,bg='black',fg='spring green')
b6.place(relx =0.10,rely=0.48,height=44,width=57)


b7 = Button(root,text = '''2''',command=lambda: fun('8'),height= 5, width=10,bg='black',fg='spring green')
b7.place(relx =0.32,rely=0.48,height=44,width=57)

b8 = Button(root,text = '''3''',command=lambda: fun('9'),height= 5, width=10,bg='black',fg='spring green')
b8.place(relx =0.54,rely=0.48,height=44,width=57)

b9 = Button(root,text = '''0''',command=lambda: fun('0'),height= 5, width=10,bg='black',fg='spring green')
b9.place(relx =0.10,rely=0.60,height=44,width=140)
#----------------------operator design------------------------------------------
b10 = Button(root,text = '''/''',command=lambda: fun('/'),height= 5, width=10,bg='black',fg='spring green')
b10.place(relx =0.79,rely=0.60,height=44,width=57)




b11= Button(root,text = '''.''',command=lambda: fun('.'),height= 5, width=10,bg='black',fg='spring green')
b11.place(relx =0.54,rely=0.60,height=44,width=57)

b12 = Button(root,text = '''+''',command=lambda: fun('+'),height= 5, width=10,bg='black',fg='spring green')
b12.place(relx =0.79,rely=0.21,height=44,width=57)

b13 = Button(root,text = '''-''',command=lambda: fun('-'),height= 5, width=10,bg='black',fg='spring green')
b13.place(relx =0.79,rely=0.34,height=44,width=57)

b14 = Button(root,text = '''*''',command=lambda: fun('*'),height= 5, width=10,bg='black',fg='spring green')
b14.place(relx =0.79,rely=0.48,height=44,width=57)

b15 = Button(root,text = '''RESULT''',command=Result,height= 5, width=10,bg='black',fg='spring green')
b15.place(relx =0.10,rely=0.73,height=44,width=335)
b15 = Button(root,text = '''Clear''',command=reset,height= 5, width=10,bg='black',fg='spring green')
b15.place(relx =0.10,rely=0.86,height=44,width=335)

root.mainloop()
